# %% [markdown]
# ### Table of Contents
# * [Markdown Language](#Markdown-Language)
#     * [การใส่บุลเลท](#การใส่บุลเลท)
#     * [การขึ้นบรรทัดใหม่](#การขึ้นบรรทัดใหม่)
#     * [การเน้นข้อความ](#การเน้นข้อความ)
#     * [การใส่สี](#การใส่สี)
#     * [การใส่ลิ้งก์](#Hyperlink)
#     * [การใส่รูป](#Image)
#     * [การใส่วิดีโอ](#Youtube-Video)
#     * [การใส่หน้าเว็บ](#Website)
#     * [การใส่ PDF](#PDF)

# %% [markdown]
# ### <span style=color:white>Markdown Language</span>
# Markdown Language
# # Heading 1
# ## Heading 2
# Markup Language (HTML)
# <H1>Heading 1<H1>
# <H2>Heading 2<H2>

# %% [markdown]
# ### การใส่บุลเลท

# %% [markdown]
# * Coffee
# * Tea
# * Water
# 1. Coffee
#     * Mocha
#     * Latte
#     * Espresso
# 2. Tea
# 3. Water

# %% [markdown]
# ### การขึ้นบรรทัดใหม่
# (ต้องกด  spacebar 2ครั้งก่อนกด enter ถึงจะขึ้นบรทัดใหม่ให้เราจริงๆ)

# %% [markdown]
# first line.
# second line.
# third line.
#
# first line.
# second line.
# third line.

# %% [markdown]
# ### การเน้นข้อความ
# (ใส่ * ครอบกี่ตัวก็ดูเอา)

# %% [markdown]
# ทำตัว*เอียง*ตรงนี้
# ทำตัว**หนา**ตรงนี้
# ทำตัว***หนาและเอียง***ตรงนี้
# ทำ~~ขีดฆ่า~~ตรงนี้

# %% [markdown]
# ### การใส่สี
# (นำเอาแท็กของ markup มาช่วย)

# %% [markdown]
# This is the <span style=color:red>last</span> chance.
# This is the <span style=color:blue;font-size:200%>last</span> chance.

# %% [markdown]
# ### Hyperlink

# %% [markdown]
# https://youtube.com.
#
# [Youtube](https://youtube.com)

# %% [markdown]
# ### Image

# %% [markdown]
# ![](https://cdn.pixabay.com/photo/2022/09/08/05/35/fog-7440132_1280.jpg)

# %% [markdown]
# ### Youtube Video
# ดึงวีดีโอยูทูปโดยการใช้แพคเกจ IPython.display (YouTubeVideo)
# นำรหัส uniqueID 8ตัว (รหัสที่อยู่หลัง watch?v=) มาใส่
# นอกจาก VDOแล้ว, IPython.display ยังใช้กับการใส่ไฟล์ประเภทต่างๆทั้ง
# .txt .csv .json audio file, image file etc.

# %%
from IPython.display import YouTubeVideo, IFrame, JSON, HTML, Image, SVG, Audio, FileLink, FileLinks

# %%
YouTubeVideo('OGYALEqTIQk', width=720, height=405)

# %% [markdown]
# ### Website
# ดึงหน้าเว็บไซต์โดยการใช้แพคเกจ IPython.display เช่นกัน (IFrame)
# ประยุต์ใช้เวลาเราเข้าหน้าเว็บที่เก็บโค้ดสี ก็ดึงมาเก็บไว้ที่โน๊ตบุ๊คเลย
# เวลาเราใช้ matplotlib ทำสีกราฟ จะได้ไม่ต้องไปนั่งหาจากที่อื่นอีก

# %%
IFrame("https://matplotlib.org/stable/gallery/color/named_colors.html", width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://matplotlib.org/stable/gallery/color/named_colors.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### PDF
# ดึงไฟล์ PDF โดยการใช้แพคเกจ IPython.display (IFrame)เช่นกัน

# %%
IFrame('https://res.cloudinary.com/dyd911kmh/image/upload/v1665049611/Marketing/Blog/Regular_Expressions_Cheat_Sheet.pdf', width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://res.cloudinary.com/dyd911kmh/image/upload/v1665049611/Marketing/Blog/Regular_Expressions_Cheat_Sheet.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### [Go To Top](#Table-of-Contents)
